# %%
import numpy as np
mienchia = np.linspace(0,2,11)
mienchia
# Out:
# array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ])

# %%
import numpy as np
import matplotlib.pyplot as plt

fs =  [1,2,4]
all_time = np.linspace(0,2,200)
t = all_time[:100]

for f in fs:
    y = np.sin(2* np.pi * f * t)
    plt.plot(t,y,label="{} Hz".format(f))

plt.legend()
import os
os.chdir('d:\\')
plt.savefig("basics_python.pdf")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

fs =  [1,2,4]
all_time = np.linspace(0,2,200)
t = all_time[:100]

fig, ax = plt.subplots()
for f in fs:
    y = np.sin(2 * np.pi * f * t)
    ax.plot(t,y, label="{} Hz".format(f))

plt.legend()
import os
os.chdir('d:\\')
plt.savefig("basics_python.pdf")
plt.show()

# %%
def f(x): return x**2
print(f(8))
# Out:
# 64

# %%
g = lambda x: x**2
print(g(8))
# Out:
# 64

# %%
def thue(percent): return lambda x:x * percent
hcm = thue(0.012)
hn = thue(0.01)
print(hcm(10000))
print(hn(10000))
# Out:
# 120.0
# 100.0

# %%
hinhthang = lambda f, a, b: (b-a)*(f(a)+f(b))/2
from math import exp
hinhthang(exp, 0, 1)
# Out:
# 1.8591409142295225

# %%
def hai_x(x):
    return 2*x
hinhthang(hai_x, 1, 2)
# Out:
# 3.0

# %%
def traprule(ham, trai, phai):
    return(phai-trai)*(ham(trai) + ham(phai))/2

# %%
import math
S = "bieu thuc can tinh tich phan la e^x:"
print(S + "[a,b]")
A = 0
B = 1
Y = traprule(math.exp, A,B)
print(S + "[%.1E,%.1E]:"%(A,B))
print("Gia tri xap xi: %.15E"%Y)
E = math.exp(B) - math.exp(A)
print("Gia tri chinh xac: %15E"%E)
# Out:
# bieu thuc can tinh tich phan la e^x:[a,b]
# bieu thuc can tinh tich phan la e^x:[0.0E+00,1.0E+00]:
# Gia tri xap xi: 1.859140914229523E+00
# Gia tri chinh xac:    1.718282E+00
